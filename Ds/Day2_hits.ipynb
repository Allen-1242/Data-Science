# %%
print("something")
# Out:
# something

# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sns

# %%
df1 = pd.read_csv("Hitters.csv")

# %%
df1
# Out:
#             Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       -Andy Allanson    293    66      1    30   29     14      1     293
# 1          -Alan Ashby    315    81      7    24   38     39     14    3449
# 2         -Alvin Davis    479   130     18    66   72     76      3    1624
# 3        -Andre Dawson    496   141     20    65   78     37     11    5628
# 4    -Andres Galarraga    321    87     10    39   42     30      2     396
# 5     -Alfredo Griffin    594   169      4    74   51     35     11    4408
# 6           -Al Newman    185    37      1    23    8     21      2     214
# 7     -Argenis Salazar    298    73      0    24   24      7      3     509
# 8       -Andres Thomas    323    81      6    26   32      8      2     341
# 9      -Andre Thornton    401    92     17    49   66     65     13    5206
# 10      -Alan Trammell    574   159     21   107   75     59     10    4631
# ...

# %%
df_x = pd.DataFrame(df1, columns=["Atbat","Hits","Hmrun","Runs", "RBI","Salary","League","Walks","Years"])

# %%
mat.plot(df_x.Hits,
df_x.Salary,
ls ='', marker='o',)
mat.xlabel("Hits") # x-axis
mat.ylabel("Salary") # y-axis
# Out:
# Text(0,0.5,'Salary')

# %%
#So it seems a very high hit rate is not indicative of salary increase,prehaps vaguely

# %%
mat.plot(df_x.Runs,
df_x.Salary,
ls ='', marker='o',)
mat.xlabel("Runs") # x-axis
mat.ylabel("Salary") # y-axis
# Out:
# Text(0,0.5,'Salary')

# %%
#so like home runs , we see an increase in runs gives a very slight increase in salary

# %%
mat.plot(df_x.League,
df_x.Salary,
ls ='', marker='o',)
mat.xlabel("League") # x-axis
mat.ylabel("Salary") # y-axis
# Out:
# Text(0,0.5,'Salary')

# %%
#Seems rather useless , lets cut it into twp diffrent leagues and see

# %%
df_no_A = df1[df1.League == 'A']
df_no_A
df_no_N = df1[df1.League == 'N']
df_no_N
# Out:
#             Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 1          -Alan Ashby    315    81      7    24   38     39     14    3449
# 3        -Andre Dawson    496   141     20    65   78     37     11    5628
# 4    -Andres Galarraga    321    87     10    39   42     30      2     396
# 6           -Al Newman    185    37      1    23    8     21      2     214
# 8       -Andres Thomas    323    81      6    26   32      8      2     341
# 11       -Alex Trevino    202    53      4    31   26     27      9    1876
# 12      -Andy VanSlyke    418   113     13    48   61     47      4    1512
# 14         -Bill Almon    196    43      7    29   27     30     13    3231
# 16         -Buddy Bell    568   158     20    89   75     73     15    8068
# 19        -Bruce Bochy    127    32      8    16   22     14      8     727
# 20        -Barry Bonds    413    92     16    72   48     65      1     413
# ...

# %%
df_drop = df1[df1.Salary == 'Nan']
print(df_no_missing.isnull().sum())
# Out:
# Unnamed: 0     0
# AtBat          0
# Hits           0
# HmRun          0
# Runs           0
# RBI            0
# Walks          0
# Years          0
# CAtBat         0
# CHits          0
# CHmRun         0
# CRuns          0
# CRBI           0
# CWalks         0
# League         0
# Division       0
# PutOuts        0
# Assists        0
# Errors         0
# Salary        59
# NewLeague      0
# dtype: int64

# %%
mat.hist(df_x.Salary, bins=25)
mat.title("Salary bins")
# Out:
# /home/allen/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /home/allen/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-39bea83b6502> in <module>()
# ----> 1 mat.hist(df_x.Salary, bins=25)
#       2 mat.title("Salary bins")
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3023                       histtype=histtype, align=align, orientation=orientation,
# ...
