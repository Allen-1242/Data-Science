# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy
import matplotlib.pyplot as plot
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from math import floor
import random
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
df_train = pd.read_csv("Telecom_Train.csv")
df_train.head()
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# State                  3333 non-null object
# Account_Length         3333 non-null int64
# Area_Code              3333 non-null int64
# Phone_No               3333 non-null int64
# International_Plan     3333 non-null object
# Voice_Mail_Plan        3333 non-null object
# No_Vmail_Messages      3333 non-null int64
# Total_Day_minutes      3333 non-null float64
# Total_Day_Calls        3333 non-null int64
# Total_Day_charge       3333 non-null float64
# Total_Eve_Minutes      3333 non-null float64
# Total_Eve_Calls        3333 non-null int64
# Total_Eve_Charge       3333 non-null float64
# Total_Night_Minutes    3333 non-null float64
# Total_Night_Calls      3333 non-null int64
# Total_Night_Charge     3333 non-null float64
# Total_Intl_Minutes     3333 non-null float64
# Total_Intl_Calls       3333 non-null int64
# Total_Intl_Charge      3333 non-null float64
# ...

# %%
df_test = pd.read_csv("Telecom_Test.csv")
df_test.head()
# Out:
#   State  Account_Length  Area_Code  Phone_No International_Plan  \
# 0    HI             101        510   3548815                 no
# 1    MT             137        510   3817211                 no
# 2    OH             103        408   4119481                 no
# 3    NM              99        415   4189100                 no
# 4    SC             108        415   4133643                 no
#
#   Voice_Mail_Plan  No_Vmail_Messages  Total_Day_minutes  Total_Day_Calls  \
# 0              no                  0               70.9              123
# 1              no                  0              223.6               86
# 2             yes                 29              294.7               95
# 3              no                  0              216.8              123
# 4              no                  0              197.4               78
#
#    Total_Day_charge      ...        Total_Eve_Calls  Total_Eve_Charge  \
# ...

# %%
frames = [df_train, df_test]
df = pd.concat(frames)
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3758 entries, 0 to 424
# Data columns (total 21 columns):
# State                  3758 non-null object
# Account_Length         3758 non-null int64
# Area_Code              3758 non-null int64
# Phone_No               3758 non-null int64
# International_Plan     3758 non-null object
# Voice_Mail_Plan        3758 non-null object
# No_Vmail_Messages      3758 non-null int64
# Total_Day_minutes      3758 non-null float64
# Total_Day_Calls        3758 non-null int64
# Total_Day_charge       3758 non-null float64
# Total_Eve_Minutes      3758 non-null float64
# Total_Eve_Calls        3758 non-null int64
# Total_Eve_Charge       3758 non-null float64
# Total_Night_Minutes    3758 non-null float64
# Total_Night_Calls      3758 non-null int64
# Total_Night_Charge     3758 non-null float64
# Total_Intl_Minutes     3758 non-null float64
# Total_Intl_Calls       3758 non-null int64
# Total_Intl_Charge      3758 non-null float64
# ...

# %%
df.head()
# Out:
#   State  Account_Length  Area_Code  Phone_No International_Plan  \
# 0    KS             128        415   3824657                 no
# 1    OH             107        415   3717191                 no
# 2    NJ             137        415   3581921                 no
# 3    OH              84        408   3759999                yes
# 4    OK              75        415   3306626                yes
#
#   Voice_Mail_Plan  No_Vmail_Messages  Total_Day_minutes  Total_Day_Calls  \
# 0             yes                 25              265.1              110
# 1             yes                 26              161.6              123
# 2              no                  0              243.4              114
# 3              no                  0              299.4               71
# 4              no                  0              166.7              113
#
#    Total_Day_charge      ...        Total_Eve_Calls  Total_Eve_Charge  \
# ...

# %%
print((df.isnull().sum()))
# Out:
# State                  0
# Account_Length         0
# Area_Code              0
# Phone_No               0
# International_Plan     0
# Voice_Mail_Plan        0
# No_Vmail_Messages      0
# Total_Day_minutes      0
# Total_Day_Calls        0
# Total_Day_charge       0
# Total_Eve_Minutes      0
# Total_Eve_Calls        0
# Total_Eve_Charge       0
# Total_Night_Minutes    0
# Total_Night_Calls      0
# Total_Night_Charge     0
# Total_Intl_Minutes     0
# Total_Intl_Calls       0
# Total_Intl_Charge      0
# No_CS_Calls            0
# Customer_Left          0
# dtype: int64

# %%
df1 = df1['Voice_Mail_Plan'].replace("no", 0, inplace = True)
df1 = pd.Series.to_frame(df1)
df1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-e6f209690f74> in <module>()
#       1 df1 = df1['Voice_Mail_Plan'].replace("no", 0, inplace = True)
# ----> 2 df1 = pd.Series.to_frame(df1)
#       3 df1.head()
#       4
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in to_frame(self, name)
#    1189         """
#    1190         if name is None:
# -> 1191             df = self._constructor_expanddim(self)
#    1192         else:
#    1193             df = self._constructor_expanddim({name: self})
#
# AttributeError: 'NoneType' object has no attribute '_constructor_expanddim'

# %%
df1.head()
df1 = pd.Series.to_frame(df1)

# %%
df1.head()
# Out:
#   Voice_Mail_Plan
# 0             yes
# 1             yes
# 2              no
# 3              no
# 4              no

# %%
df  = pd.concat([df,df1])
df.head()
# Out:
#    Account_Length  Area_Code Customer_Left International_Plan  No_CS_Calls  \
# 0           128.0      415.0         False                 no          1.0
# 1           107.0      415.0         False                 no          1.0
# 2           137.0      415.0         False                 no          0.0
# 3            84.0      408.0         False                yes          2.0
# 4            75.0      415.0         False                yes          3.0
#
#    No_Vmail_Messages   Phone_No State  Total_Day_Calls  Total_Day_charge  \
# 0               25.0  3824657.0    KS            110.0             45.07
# 1               26.0  3717191.0    OH            123.0             27.47
# 2                0.0  3581921.0    NJ            114.0             41.38
# 3                0.0  3759999.0    OH             71.0             50.90
# 4                0.0  3306626.0    OK            113.0             28.34
#
#         ...         Total_Eve_Calls  Total_Eve_Charge  Total_Eve_Minutes  \
# ...

# %%
df2 = df['International_Plan'].replace({'no': 0, 'yes': 1})
df2.head()
# Out:
# 0      no
# 1      no
# 2      no
# 3     yes
# 4     yes
# Name: International_Plan, dtype: object

# %%
df2 = pd.Series.to_frame(df2)
df2.head()
# Out:
#   International_Plan
# 0                 no
# 1                 no
# 2                 no
# 3                yes
# 4                yes

# %%
df = df.drop(["International_Plan", "Voice_Mail_Plan"], axis= 1)

# %%
df = pd.concat([df,df1,df2])
df.head()
# Out:
#    Account_Length  Area_Code Customer_Left International_Plan  No_CS_Calls  \
# 0           128.0      415.0         False                NaN          1.0
# 1           107.0      415.0         False                NaN          1.0
# 2           137.0      415.0         False                NaN          0.0
# 3            84.0      408.0         False                NaN          2.0
# 4            75.0      415.0         False                NaN          3.0
#
#    No_Vmail_Messages   Phone_No State  Total_Day_Calls  Total_Day_charge  \
# 0               25.0  3824657.0    KS            110.0             45.07
# 1               26.0  3717191.0    OH            123.0             27.47
# 2                0.0  3581921.0    NJ            114.0             41.38
# 3                0.0  3759999.0    OH             71.0             50.90
# 4                0.0  3306626.0    OK            113.0             28.34
#
#         ...         Total_Eve_Calls  Total_Eve_Charge  Total_Eve_Minutes  \
# ...
